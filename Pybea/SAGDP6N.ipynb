# %%
from pprint import pprint
from pybea.client import BureauEconomicAnalysisClient
import json
import pandas as pd

# %%
bea_client = BureauEconomicAnalysisClient(api_key='64C1A606-C86B-4702-A5D0-977F79A936D1')

# %%
SAGDP6N = bea_client.regional(
    table_name=['SAGDP6N'],
    line_code=1,
    geo_fips=['STATE'],
    year=['LAST10']
)
# Out:
# https://apps.bea.gov/api/data/?userid=64C1A606-C86B-4702-A5D0-977F79A936D1&method=GetData&datasetname=Regional&year=LAST10&TableName=SAGDP6N&GeoFips=STATE&LineCode=1&resultformat=JSON

# %%
SAGDP6Ndata = (SAGDP6N['BEAAPI']['Results']['Data'])

# %%
SAGDP6Ndf = pd.DataFrame(SAGDP6Ndata)
SAGDP6Ndf
# Out:
#           Code GeoFips          GeoName TimePeriod               CL_UNIT  \
# 0    SAGDP6N-1   00000  United States *       2011  Thousands of dollars
# 1    SAGDP6N-1   00000  United States *       2012  Thousands of dollars
# 2    SAGDP6N-1   00000  United States *       2013  Thousands of dollars
# 3    SAGDP6N-1   00000  United States *       2014  Thousands of dollars
# 4    SAGDP6N-1   00000  United States *       2015  Thousands of dollars
# ..         ...     ...              ...        ...                   ...
# 595  SAGDP6N-1   98000         Far West       2016  Thousands of dollars
# 596  SAGDP6N-1   98000         Far West       2017  Thousands of dollars
# 597  SAGDP6N-1   98000         Far West       2018  Thousands of dollars
# 598  SAGDP6N-1   98000         Far West       2019  Thousands of dollars
# 599  SAGDP6N-1   98000         Far West       2020  Thousands of dollars
#
#     UNIT_MULT      DataValue NoteRef
# 0           3  1,103,725,000       *
# ...

# %%
SAGDP6N_2 = bea_client.regional(
    table_name=['SAGDP6N'],
    line_code=3,
    geo_fips=['STATE'],
    year=['LAST10']
)
# Out:
# https://apps.bea.gov/api/data/?userid=64C1A606-C86B-4702-A5D0-977F79A936D1&method=GetData&datasetname=Regional&year=LAST10&TableName=SAGDP6N&GeoFips=STATE&LineCode=3&resultformat=JSON

# %%
SAGDP6N_2data = (SAGDP6N_2['BEAAPI']['Results']['Data'])
SAGDP6N_2df = pd.DataFrame(SAGDP6N_2data)
SAGDP6N_2df
# Out:
#           Code GeoFips          GeoName TimePeriod               CL_UNIT  \
# 0    SAGDP6N-3   00000  United States *       2011  Thousands of dollars
# 1    SAGDP6N-3   00000  United States *       2012  Thousands of dollars
# 2    SAGDP6N-3   00000  United States *       2013  Thousands of dollars
# 3    SAGDP6N-3   00000  United States *       2014  Thousands of dollars
# 4    SAGDP6N-3   00000  United States *       2015  Thousands of dollars
# ..         ...     ...              ...        ...                   ...
# 595  SAGDP6N-3   98000         Far West       2016  Thousands of dollars
# 596  SAGDP6N-3   98000         Far West       2017  Thousands of dollars
# 597  SAGDP6N-3   98000         Far West       2018  Thousands of dollars
# 598  SAGDP6N-3   98000         Far West       2019  Thousands of dollars
# 599  SAGDP6N-3   98000         Far West       2020  Thousands of dollars
#
#     UNIT_MULT   DataValue NoteRef
# 0           3   9,532,000       *
# ...
