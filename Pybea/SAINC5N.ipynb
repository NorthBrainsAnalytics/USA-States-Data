# %%
from pprint import pprint
from pybea.client import BureauEconomicAnalysisClient
import json
import pandas as pd

# %%
bea_client = BureauEconomicAnalysisClient(api_key='64C1A606-C86B-4702-A5D0-977F79A936D1')

# %%
SAINC5N = bea_client.regional(
    table_name=['SAINC5N'],
    line_code=10,
    geo_fips=['STATE'],
    year=['LAST10']
)
# Out:
# https://apps.bea.gov/api/data/?userid=64C1A606-C86B-4702-A5D0-977F79A936D1&method=GetData&datasetname=Regional&year=LAST10&TableName=SAINC5N&GeoFips=STATE&LineCode=10&resultformat=JSON

# %%
SAINC5Ndata = (SAINC5N['BEAAPI']['Results']['Data'])
SAINC5Ndf = pd.DataFrame(SAINC5Ndata)
SAINC5Ndf
# Out:
#            Code GeoFips        GeoName TimePeriod               CL_UNIT  \
# 0    SAINC5N-10   00000  United States       2012  Thousands of dollars
# 1    SAINC5N-10   00000  United States       2013  Thousands of dollars
# 2    SAINC5N-10   00000  United States       2014  Thousands of dollars
# 3    SAINC5N-10   00000  United States       2015  Thousands of dollars
# 4    SAINC5N-10   00000  United States       2016  Thousands of dollars
# ..          ...     ...            ...        ...                   ...
# 595  SAINC5N-10   98000       Far West       2017  Thousands of dollars
# 596  SAINC5N-10   98000       Far West       2018  Thousands of dollars
# 597  SAINC5N-10   98000       Far West       2019  Thousands of dollars
# 598  SAINC5N-10   98000       Far West       2020  Thousands of dollars
# 599  SAINC5N-10   98000       Far West       2021  Thousands of dollars
#
#     UNIT_MULT       DataValue
# 0           3  14,003,346,000
# 1           3  14,189,228,000
# 2           3  14,969,527,000
# 3           3  15,681,233,000
# 4           3  16,092,713,000
# ..        ...             ...
# 595         3   3,201,394,128
# 596         3   3,367,569,391
# 597         3   3,527,996,046
# 598         3   3,816,145,032
# 599         3   4,130,501,154
#
# [600 rows x 7 columns]
