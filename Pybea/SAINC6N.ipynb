# %%
from pprint import pprint
from pybea.client import BureauEconomicAnalysisClient
import json
import pandas as pd

# %%
bea_client = BureauEconomicAnalysisClient(api_key='64C1A606-C86B-4702-A5D0-977F79A936D1')

# %%
SAINC6N = bea_client.regional(
    table_name=['SAINC6N'],
    line_code=1,
    geo_fips=['STATE'],
    year=['LAST10']
)
# Out:
# https://apps.bea.gov/api/data/?userid=64C1A606-C86B-4702-A5D0-977F79A936D1&method=GetData&datasetname=Regional&year=LAST10&TableName=SAINC6N&GeoFips=STATE&LineCode=1&resultformat=JSON

# %%
SAINC6Ndata = (SAINC6N['BEAAPI']['Results']['Data'])
SAINC6Ndf = pd.DataFrame(SAINC6Ndata)
SAINC6Ndf
# Out:
#           Code GeoFips        GeoName TimePeriod               CL_UNIT  \
# 0    SAINC6N-1   00000  United States       2012  Thousands of dollars
# 1    SAINC6N-1   00000  United States       2013  Thousands of dollars
# 2    SAINC6N-1   00000  United States       2014  Thousands of dollars
# 3    SAINC6N-1   00000  United States       2015  Thousands of dollars
# 4    SAINC6N-1   00000  United States       2016  Thousands of dollars
# ..         ...     ...            ...        ...                   ...
# 595  SAINC6N-1   98000       Far West       2017  Thousands of dollars
# 596  SAINC6N-1   98000       Far West       2018  Thousands of dollars
# 597  SAINC6N-1   98000       Far West       2019  Thousands of dollars
# 598  SAINC6N-1   98000       Far West       2020  Thousands of dollars
# 599  SAINC6N-1   98000       Far West       2021  Thousands of dollars
#
#     UNIT_MULT      DataValue
# 0           3  8,550,417,000
# 1           3  8,819,078,000
# 2           3  9,234,825,000
# 3           3  9,685,115,000
# 4           3  9,952,886,000
# ..        ...            ...
# 595         3  2,012,882,086
# 596         3  2,130,291,394
# 597         3  2,246,204,657
# 598         3  2,299,560,193
# 599         3  2,556,810,284
#
# [600 rows x 7 columns]
